# %%
print("hello") # testing jupyter nb
# Out:
# hello

# %%
import pandas as pd # importing pandas module for data analysis tasks 
import matplotlib as plt

# %%
x = pd.read_csv("C:\\Users\\moomo\\OneDrive\\Desktop\\fraud_data.csv",  # function in pandas--read_csv("file path")
               dtype = {'amt': float})  # solved amt-object dtype problem!!!    --convert dtype after read_csv command

# %%
x.head() # get idea of what data consists of first 5 rows
# Out:
#   trans_time                   merchant       category     amt  \
# 0   12:00 AM  Heller, Gutmann and Zieme        grocery  107.23
# 1   12:00 AM             Lind-Buckridge  entertainment  220.11
# 2   12:07 AM                  Kiehn Inc        grocery   96.29
# 3   12:09 AM                Beier-Hyatt       shopping    7.77
# 4   12:21 AM                 Bruen-Yost           misc    6.85
#
#                        City state      lat      long  city_pop  \
# 0                    Orient    WA  48.8878 -118.2105       149
# 1                Malad City    ID  42.1808 -112.2620      4154
# 2                   Grenada    CA  41.6125 -122.5258       589
# 3  High Rolls Mountain Park    NM  32.9396 -105.8189       899
# 4                   Freedom    WY  43.0172 -111.0292       471
#
#                                  job         dob  \
# 0  Special educational needs teacher   6/21/1978
# 1        Nature conservation officer   1/19/1962
# 2                    Systems analyst  12/21/1945
# ...

# %%
x.shape # rows and columns of the data
# Out:
# (100, 15)

# %%
x.columns # all the columns
# Out:
# Index(['trans_time', 'merchant', 'category', 'amt', 'City', 'state', 'lat',
#        'long', 'city_pop', 'job', 'dob', 'trans_num', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
x.head(2) # pull 2 rows to get idea of the data
# Out:
#   trans_time                   merchant       category     amt        City  \
# 0   12:00 AM  Heller, Gutmann and Zieme        grocery  107.23      Orient
# 1   12:00 AM             Lind-Buckridge  entertainment  220.11  Malad City
#
#   state      lat      long  city_pop                                job  \
# 0    WA  48.8878 -118.2105       149  Special educational needs teacher
# 1    ID  42.1808 -112.2620      4154        Nature conservation officer
#
#          dob                         trans_num  merch_lat  merch_long  \
# 0  6/21/1978  1f76529f8574734946361c461b024d99  49.159047 -118.186462
# 1  1/19/1962  a1a22d70485983eac12b5b88dad1cf95  43.150704 -112.154481
#
#    is_fraud
# 0         0
# 1         0

# %%
x.dtypes
# Out:
# trans_time     object
# merchant       object
# category       object
# amt           float64
# City           object
# state          object
# lat           float64
# long          float64
# city_pop        int64
# job            object
# dob            object
# trans_num      object
# merch_lat     float64
# merch_long    float64
# is_fraud        int64
# dtype: object

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   trans_time  100 non-null    object
#  1   merchant    100 non-null    object
#  2   category    100 non-null    object
#  3   amt         100 non-null    float64
#  4   City        100 non-null    object
#  5   state       100 non-null    object
#  6   lat         100 non-null    float64
#  7   long        100 non-null    float64
#  8   city_pop    100 non-null    int64
#  9   job         100 non-null    object
#  10  dob         100 non-null    object
#  11  trans_num   100 non-null    object
#  12  merch_lat   100 non-null    float64
#  13  merch_long  100 non-null    float64
#  14  is_fraud    100 non-null    int64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 11.8+ KB

# %%
#x.head()

#x[x.state == "CA"].count

x.state.value_counts() # 26 transactions from CA, the most. Lot of wealth?
# Out:
# state
# CA    26
# MO    18
# NE    10
# WY     8
# OR     8
# WA     6
# CO     6
# ID     4
# UT     4
# NM     3
# HI     3
# AZ     3
# AK     1
# Name: count, dtype: int64

# %%
x[x.category == "entertainment"] # entertainment for $220.11 sounds faulty--Lind-Buckridge--call ASAP to confirm purchase
# Out:
#    trans_time                    merchant       category     amt        City  \
# 1    12:00 AM              Lind-Buckridge  entertainment  220.11  Malad City
# 55    3:12 AM  Cormier, Stracke and Thiel  entertainment    3.14     Honokaa
#
#    state      lat     long  city_pop                          job        dob  \
# 1     ID  42.1808 -112.262      4154  Nature conservation officer  1/19/1962
# 55    HI  20.0827 -155.488      4878              Physiotherapist  12/3/1966
#
#                            trans_num  merch_lat  merch_long  is_fraud
# 1   a1a22d70485983eac12b5b88dad1cf95  43.150704 -112.154481         0
# 55  cb117fff5645082a2525119c1eafec53  20.995398 -155.369362         0

# %%
x.category.value_counts()
# Out:
# category
# grocery          31
# gastransport     27
# shopping         21
# misc             19
# entertainment     2
# Name: count, dtype: int64

# %%
x[x.category == "grocery"] # transac. # 53 could be faulty--grocery purchase of #202.71 at 3:07 am--check with Miller-Hauck
# Out:
#    trans_time                       merchant category     amt  \
# 0    12:00 AM      Heller, Gutmann and Zieme  grocery  107.23
# 2    12:07 AM                      Kiehn Inc  grocery   96.29
# 5    12:22 AM                      Kunze Inc  grocery   90.22
# 9    12:34 AM                  Stracke-Lemke  grocery   83.07
# 17    1:02 AM                       Wolf Inc  grocery   89.11
# 18    1:04 AM                Vandervort-Funk  grocery   50.68
# 24    1:23 AM                    Bauch-Rayno  grocery  122.05
# 25    1:34 AM                    Hills-Olson  grocery   27.03
# 29    2:06 AM                    Bradtke PLC  grocery   78.13
# 33    2:12 AM                     Lockman Lt  grocery  104.08
# 35    2:14 AM                    Bauch-Rayno  grocery  192.82
# 37    2:21 AM  Johnston, Nikolaus and Maggio  grocery   41.01
# 39    2:28 AM                       Doyle Lt  grocery  157.07
# 41    2:32 AM                     Spinka Inc  grocery   57.57
# ...

# %%
x.head()
# Out:
#   trans_time                   merchant       category     amt  \
# 0   12:00 AM  Heller, Gutmann and Zieme        grocery  107.23
# 1   12:00 AM             Lind-Buckridge  entertainment  220.11
# 2   12:07 AM                  Kiehn Inc        grocery   96.29
# 3   12:09 AM                Beier-Hyatt       shopping    7.77
# 4   12:21 AM                 Bruen-Yost           misc    6.85
#
#                        City state      lat      long  city_pop  \
# 0                    Orient    WA  48.8878 -118.2105       149
# 1                Malad City    ID  42.1808 -112.2620      4154
# 2                   Grenada    CA  41.6125 -122.5258       589
# 3  High Rolls Mountain Park    NM  32.9396 -105.8189       899
# 4                   Freedom    WY  43.0172 -111.0292       471
#
#                                  job         dob  \
# 0  Special educational needs teacher   6/21/1978
# 1        Nature conservation officer   1/19/1962
# 2                    Systems analyst  12/21/1945
# ...

# %% [markdown]
# # jupyter not recognizing 'amount' column as string values

# %%
#x['amount'].describe() 
x.dtypes # amount column contains objects--objects don't apply to describe() function 

# change amount column data type to float 

x.info()

#x['amt'] = x['amt'].astype('int64')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   trans_time  100 non-null    object
#  1   merchant    100 non-null    object
#  2   category    100 non-null    object
#  3   amt         100 non-null    float64
#  4   City        100 non-null    object
#  5   state       100 non-null    object
#  6   lat         100 non-null    float64
#  7   long        100 non-null    float64
#  8   city_pop    100 non-null    int64
#  9   job         100 non-null    object
#  10  dob         100 non-null    object
#  11  trans_num   100 non-null    object
#  12  merch_lat   100 non-null    float64
#  13  merch_long  100 non-null    float64
#  14  is_fraud    100 non-null    int64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 11.8+ KB

# %%
x.info()

x.amt = [str(y) if type(y)==object else y for y in x.amt]



#x.amt = [int(x) if type(x)==object else x for x in x.amt]

x.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   trans_time  100 non-null    object
#  1   merchant    100 non-null    object
#  2   category    100 non-null    object
#  3   amt         100 non-null    float64
#  4   City        100 non-null    object
#  5   state       100 non-null    object
#  6   lat         100 non-null    float64
#  7   long        100 non-null    float64
#  8   city_pop    100 non-null    int64
#  9   job         100 non-null    object
#  10  dob         100 non-null    object
#  11  trans_num   100 non-null    object
#  12  merch_lat   100 non-null    float64
#  13  merch_long  100 non-null    float64
#  14  is_fraud    100 non-null    int64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 11.8+ KB
#                amt         lat        long      city_pop   merch_lat  \
# ...

# %% [markdown]
# ### converted amt column data type from object to float64! --dtype = {'amt': float} addition after read_csv command
# #### now able to execute describe() on amt column

# %%
x.describe() # average money spent on all transactions is ~$93 

#x.head()

x[x.amt == 1055.47] # learn wildcard operators to find specific transactions using amt 

# 100 transactions 
# max transaction is $1,055 --already looks dubious --contact Kassulke PLC ASAP
# Out:
#    trans_time      merchant  category      amt   City state      lat  \
# 47    2:54 AM  Kassulke PLC  shopping  1055.47  Iliff    CO  40.7692
#
#         long  city_pop                    job        dob  \
# 47 -103.0968       648  Community arts worker  9/21/1969
#
#                            trans_num  merch_lat  merch_long  is_fraud
# 47  adca67d0a40b26fb8afeccbae31b7828  39.940564 -103.528231         0
